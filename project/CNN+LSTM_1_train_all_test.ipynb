# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,LSTM,BatchNormalization,MaxPooling2D,Reshape
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
person_train_valid = np.load("person_train_valid.npy")
print("Train valid Shape:", person_train_valid.shape)
print("Train max:", np.max(person_train_valid))
print("Train min:", np.min(person_train_valid))
num_zeros = np.count_nonzero(person_train_valid == 0)
print("Number of zeros in person_train_valid:", num_zeros)

person_test = np.load("person_test.npy")
print("Test valid Shape:", person_test.shape)
print("Test max:", np.max(person_test))
print("Test min:", np.min(person_test))
# Out:
# Train valid Shape: (2115, 1)
# Train max: 8.0
# Train min: 0.0
# Number of zeros in person_train_valid: 237
# Test valid Shape: (443, 1)
# Test max: 8.0
# Test min: 0.0

# %%
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
print(X_train_valid.shape)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

## Visualizing the data

ch_data = X_train_valid[:,8,:]


class_0_ind = np.where(y_train_valid == 0)
ch_data_class_0 = ch_data[class_0_ind]
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0)


class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

_=plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])
# Out:
# (2115, 22, 1000)

# %%
def train_data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,800)
    X = X[:,:,0:800]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,800) -> (sample,22,800/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    print('Shape of Y:',total_y.shape)
    return total_X,total_y


def test_data_prep(X):
    
    total_X = None
    
    
    # Trimming the data (sample,22,1000) -> (sample,22,800)
    X = X[:,:,0:800]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,800) -> (sample,22,800/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, 2), axis=3)
    
    
    total_X = X_max
    print('Shape of X after maxpooling:',total_X.shape)
    
    return total_X

# %%
idx_subject = 0
mask = person_train_valid.flatten() == idx_subject
X_train_valid_single = X_train_valid[mask]
y_train_valid_single = y_train_valid[mask]
num_subject_trial = np.count_nonzero(mask)

## Random splitting

# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(num_subject_trial, round(0.2*num_subject_trial), replace=False)
ind_train = np.array(list(set(range(num_subject_trial)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
X_train, X_valid = X_train_valid_single[ind_train], X_train_valid_single[ind_valid] 
y_train, y_valid = y_train_valid_single[ind_train], y_train_valid_single[ind_valid]

## Preprocessing the dataset

x_train, y_train = train_data_prep(X_train, y_train, 2, 2, True)
x_valid, y_valid = train_data_prep(X_valid, y_valid, 2, 2, True)

print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
X_test_prep = test_data_prep(X_test)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of X after trimming: (190, 22, 800)
# Shape of X after maxpooling: (190, 22, 400)
# Shape of X after averaging+noise and concatenating: (380, 22, 400)
# Shape of X after subsampling and concatenating: (760, 22, 400)
# Shape of Y: (760,)
# Shape of X after trimming: (47, 22, 800)
# Shape of X after maxpooling: (47, 22, 400)
# Shape of X after averaging+noise and concatenating: (94, 22, 400)
# Shape of X after subsampling and concatenating: (188, 22, 400)
# Shape of Y: (188,)
# Shape of training set: (760, 22, 400)
# Shape of validation set: (188, 22, 400)
# Shape of training labels: (760,)
# Shape of validation labels: (188,)
# Shape of X after trimming: (443, 22, 800)
# Shape of X after maxpooling: (443, 22, 400)
# Shape of training labels after categorical conversion: (760, 4)
# Shape of validation labels after categorical conversion: (188, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (760, 22, 400, 1)
# Shape of validation set after adding width info: (188, 22, 400, 1)
# Shape of test set after adding width info: (443, 22, 400, 1)
# Shape of training set after dimension reshaping: (760, 400, 1, 22)
# Shape of validation set after dimension reshaping: (188, 400, 1, 22)
# Shape of test set after dimension reshaping: (443, 400, 1, 22)

# %%
# Building the CNN model using sequential class
hybrid_cnn_lstm_model = Sequential()

# Conv. block 1
hybrid_cnn_lstm_model.add(Conv2D(filters=10, kernel_size=(5,1), padding='same', activation='elu', input_shape=(400,1,22)))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.6))

# Conv. block 2
hybrid_cnn_lstm_model.add(Conv2D(filters=15, kernel_size=(5,1), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.6))

# Conv. block 3
hybrid_cnn_lstm_model.add(Conv2D(filters=20, kernel_size=(5,1), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.6))

# Conv. block 4
hybrid_cnn_lstm_model.add(Conv2D(filters=25, kernel_size=(5,1), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.6))

# FC+LSTM layers
hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_lstm_model.add(Dense((40))) # FC layer with 100 units
hybrid_cnn_lstm_model.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_lstm_model.add(LSTM(10, dropout=0.4, recurrent_dropout=0.1, input_shape=(40,1), return_sequences=False))


# Output layer with Softmax activation 
hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_lstm_model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 400, 1, 10)        1110
#
#  max_pooling2d (MaxPooling2D  (None, 134, 1, 10)       0
#  )
#
#  batch_normalization (BatchN  (None, 134, 1, 10)       40
#  ormalization)
#
#  dropout (Dropout)           (None, 134, 1, 10)        0
#
#  conv2d_1 (Conv2D)           (None, 134, 1, 15)        765
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 1, 15)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 45, 1, 15)        60
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 45, 1, 15)         0
#
#  conv2d_2 (Conv2D)           (None, 45, 1, 20)         1520
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 1, 20)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 15, 1, 20)        80
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 15, 1, 20)         0
#
#  conv2d_3 (Conv2D)           (None, 15, 1, 25)         2525
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 1, 25)         0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 5, 1, 25)         100
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 5, 1, 25)          0
#
#  flatten (Flatten)           (None, 125)               0
#
#  dense (Dense)               (None, 40)                5040
#
#  reshape (Reshape)           (None, 40, 1)             0
#
#  lstm (LSTM)                 (None, 10)                480
#
#  dense_1 (Dense)             (None, 4)                 44
#
# =================================================================
# Total params: 11,764
# Trainable params: 11,624
# Non-trainable params: 140
# _________________________________________________________________

# %%
# Model parameters
learning_rate = 1e-3
epochs = 100
hybrid_cnn_lstm_optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
# Compiling the model
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_cnn_lstm_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 5s 158ms/step - loss: 1.3900 - accuracy: 0.2592 - val_loss: 1.4401 - val_accuracy: 0.2553
# Epoch 2/100
# 12/12 [==============================] - 2s 134ms/step - loss: 1.3869 - accuracy: 0.2658 - val_loss: 1.4216 - val_accuracy: 0.2553
# Epoch 3/100
# 12/12 [==============================] - 2s 139ms/step - loss: 1.3867 - accuracy: 0.2618 - val_loss: 1.4092 - val_accuracy: 0.2553
# Epoch 4/100
# 12/12 [==============================] - 2s 145ms/step - loss: 1.3857 - accuracy: 0.2526 - val_loss: 1.4039 - val_accuracy: 0.2553
# Epoch 5/100
# 12/12 [==============================] - 2s 136ms/step - loss: 1.3850 - accuracy: 0.2750 - val_loss: 1.3966 - val_accuracy: 0.2606
# Epoch 6/100
# 12/12 [==============================] - 2s 137ms/step - loss: 1.3830 - accuracy: 0.2658 - val_loss: 1.3925 - val_accuracy: 0.2660
# Epoch 7/100
# 12/12 [==============================] - 2s 135ms/step - loss: 1.3801 - accuracy: 0.2697 - val_loss: 1.3878 - val_accuracy: 0.2819
# Epoch 8/100
# 12/12 [==============================] - 2s 142ms/step - loss: 1.3818 - accuracy: 0.2868 - val_loss: 1.3793 - val_accuracy: 0.3032
# Epoch 9/100
# 12/12 [==============================] - 2s 140ms/step - loss: 1.3712 - accuracy: 0.3171 - val_loss: 1.3703 - val_accuracy: 0.3245
# Epoch 10/100
# 12/12 [==============================] - 2s 141ms/step - loss: 1.3679 - accuracy: 0.3000 - val_loss: 1.3596 - val_accuracy: 0.3085
# Epoch 11/100
# 12/12 [==============================] - 2s 140ms/step - loss: 1.3635 - accuracy: 0.3105 - val_loss: 1.3518 - val_accuracy: 0.3298
# Epoch 12/100
# 12/12 [==============================] - 2s 142ms/step - loss: 1.3568 - accuracy: 0.3026 - val_loss: 1.3541 - val_accuracy: 0.3245
# Epoch 13/100
# 12/12 [==============================] - 2s 139ms/step - loss: 1.3482 - accuracy: 0.3237 - val_loss: 1.3744 - val_accuracy: 0.3298
# Epoch 14/100
# 12/12 [==============================] - 2s 138ms/step - loss: 1.3106 - accuracy: 0.3592 - val_loss: 1.4256 - val_accuracy: 0.3191
# Epoch 15/100
# 12/12 [==============================] - 2s 138ms/step - loss: 1.2695 - accuracy: 0.3947 - val_loss: 1.4903 - val_accuracy: 0.3351
# Epoch 16/100
# 12/12 [==============================] - 2s 136ms/step - loss: 1.2485 - accuracy: 0.3803 - val_loss: 1.5568 - val_accuracy: 0.3191
# Epoch 17/100
# 12/12 [==============================] - 2s 142ms/step - loss: 1.2073 - accuracy: 0.3987 - val_loss: 1.5946 - val_accuracy: 0.2234
# Epoch 18/100
# 12/12 [==============================] - 2s 138ms/step - loss: 1.1533 - accuracy: 0.4434 - val_loss: 1.6063 - val_accuracy: 0.2181
# Epoch 19/100
# 12/12 [==============================] - 2s 137ms/step - loss: 1.1047 - accuracy: 0.4789 - val_loss: 1.5439 - val_accuracy: 0.2021
# Epoch 20/100
# 12/12 [==============================] - 2s 134ms/step - loss: 1.1143 - accuracy: 0.4605 - val_loss: 1.6170 - val_accuracy: 0.3404
# Epoch 21/100
# 12/12 [==============================] - 2s 140ms/step - loss: 1.0716 - accuracy: 0.4645 - val_loss: 1.5154 - val_accuracy: 0.3617
# Epoch 22/100
# 12/12 [==============================] - 2s 137ms/step - loss: 1.0756 - accuracy: 0.4697 - val_loss: 1.5408 - val_accuracy: 0.3511
# Epoch 23/100
# 12/12 [==============================] - 2s 139ms/step - loss: 1.0457 - accuracy: 0.4842 - val_loss: 1.4154 - val_accuracy: 0.3883
# Epoch 24/100
# 12/12 [==============================] - 2s 142ms/step - loss: 1.0086 - accuracy: 0.4868 - val_loss: 1.4694 - val_accuracy: 0.3777
# Epoch 25/100
# 12/12 [==============================] - 2s 141ms/step - loss: 1.0044 - accuracy: 0.4882 - val_loss: 1.4282 - val_accuracy: 0.3936
# Epoch 26/100
# 12/12 [==============================] - 2s 136ms/step - loss: 1.0302 - accuracy: 0.4789 - val_loss: 1.4373 - val_accuracy: 0.3883
# Epoch 27/100
# 12/12 [==============================] - 2s 134ms/step - loss: 1.0176 - accuracy: 0.5118 - val_loss: 1.4279 - val_accuracy: 0.3777
# Epoch 28/100
# 12/12 [==============================] - 2s 134ms/step - loss: 1.0107 - accuracy: 0.4961 - val_loss: 1.4545 - val_accuracy: 0.3777
# Epoch 29/100
# 12/12 [==============================] - 2s 147ms/step - loss: 1.0029 - accuracy: 0.4895 - val_loss: 1.4734 - val_accuracy: 0.3830
# Epoch 30/100
# 12/12 [==============================] - 2s 137ms/step - loss: 0.9800 - accuracy: 0.5132 - val_loss: 1.4724 - val_accuracy: 0.3564
# Epoch 31/100
# 12/12 [==============================] - 2s 134ms/step - loss: 0.9712 - accuracy: 0.5145 - val_loss: 1.4440 - val_accuracy: 0.3883
# Epoch 32/100
# 12/12 [==============================] - 3s 276ms/step - loss: 0.9674 - accuracy: 0.5105 - val_loss: 1.4757 - val_accuracy: 0.3883
# Epoch 33/100
# 12/12 [==============================] - 5s 466ms/step - loss: 0.9570 - accuracy: 0.5289 - val_loss: 1.4833 - val_accuracy: 0.3830
# Epoch 34/100
# 12/12 [==============================] - 5s 421ms/step - loss: 0.9358 - accuracy: 0.5500 - val_loss: 1.4499 - val_accuracy: 0.4043
# Epoch 35/100
# 12/12 [==============================] - 5s 430ms/step - loss: 0.9386 - accuracy: 0.5276 - val_loss: 1.5346 - val_accuracy: 0.3883
# Epoch 36/100
# 12/12 [==============================] - 5s 465ms/step - loss: 0.9186 - accuracy: 0.5697 - val_loss: 1.4968 - val_accuracy: 0.3936
# Epoch 37/100
# 12/12 [==============================] - 4s 337ms/step - loss: 0.9365 - accuracy: 0.5355 - val_loss: 1.5175 - val_accuracy: 0.3777
# Epoch 38/100
# 12/12 [==============================] - 3s 218ms/step - loss: 0.8983 - accuracy: 0.5539 - val_loss: 1.5185 - val_accuracy: 0.3777
# Epoch 39/100
# 12/12 [==============================] - 2s 135ms/step - loss: 0.9120 - accuracy: 0.5579 - val_loss: 1.5007 - val_accuracy: 0.4096
# Epoch 40/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.9072 - accuracy: 0.5421 - val_loss: 1.4769 - val_accuracy: 0.4043
# Epoch 41/100
# 12/12 [==============================] - 2s 136ms/step - loss: 0.8882 - accuracy: 0.5566 - val_loss: 1.5106 - val_accuracy: 0.3830
# Epoch 42/100
# 12/12 [==============================] - 2s 136ms/step - loss: 0.8686 - accuracy: 0.5566 - val_loss: 1.4600 - val_accuracy: 0.4149
# Epoch 43/100
# 12/12 [==============================] - 2s 131ms/step - loss: 0.8913 - accuracy: 0.5368 - val_loss: 1.4492 - val_accuracy: 0.4202
# Epoch 44/100
# 12/12 [==============================] - 2s 143ms/step - loss: 0.8918 - accuracy: 0.5605 - val_loss: 1.4087 - val_accuracy: 0.4415
# Epoch 45/100
# 12/12 [==============================] - 2s 133ms/step - loss: 0.8754 - accuracy: 0.5592 - val_loss: 1.4660 - val_accuracy: 0.4415
# Epoch 46/100
# 12/12 [==============================] - 2s 136ms/step - loss: 0.8515 - accuracy: 0.5882 - val_loss: 1.4504 - val_accuracy: 0.4681
# Epoch 47/100
# 12/12 [==============================] - 2s 135ms/step - loss: 0.8360 - accuracy: 0.6013 - val_loss: 1.4559 - val_accuracy: 0.4255
# Epoch 48/100
# 12/12 [==============================] - 2s 146ms/step - loss: 0.8364 - accuracy: 0.5711 - val_loss: 1.3728 - val_accuracy: 0.4681
# Epoch 49/100
# 12/12 [==============================] - 2s 141ms/step - loss: 0.8353 - accuracy: 0.5908 - val_loss: 1.4298 - val_accuracy: 0.4681
# Epoch 50/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.8417 - accuracy: 0.5816 - val_loss: 1.4738 - val_accuracy: 0.4521
# Epoch 51/100
# 12/12 [==============================] - 2s 147ms/step - loss: 0.8298 - accuracy: 0.6039 - val_loss: 1.5161 - val_accuracy: 0.4309
# Epoch 52/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.8146 - accuracy: 0.6197 - val_loss: 1.5142 - val_accuracy: 0.4521
# Epoch 53/100
# 12/12 [==============================] - 2s 136ms/step - loss: 0.8264 - accuracy: 0.6053 - val_loss: 1.4952 - val_accuracy: 0.4521
# Epoch 54/100
# 12/12 [==============================] - 2s 133ms/step - loss: 0.8015 - accuracy: 0.6303 - val_loss: 1.4889 - val_accuracy: 0.4521
# Epoch 55/100
# 12/12 [==============================] - 2s 142ms/step - loss: 0.7971 - accuracy: 0.6197 - val_loss: 1.4812 - val_accuracy: 0.4574
# Epoch 56/100
# 12/12 [==============================] - 2s 135ms/step - loss: 0.8251 - accuracy: 0.6132 - val_loss: 1.5250 - val_accuracy: 0.4415
# Epoch 57/100
# 12/12 [==============================] - 2s 145ms/step - loss: 0.8310 - accuracy: 0.6000 - val_loss: 1.4430 - val_accuracy: 0.4787
# Epoch 58/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.7957 - accuracy: 0.6184 - val_loss: 1.4656 - val_accuracy: 0.4521
# Epoch 59/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.8185 - accuracy: 0.6026 - val_loss: 1.4319 - val_accuracy: 0.4787
# Epoch 60/100
# 12/12 [==============================] - 2s 133ms/step - loss: 0.7993 - accuracy: 0.6197 - val_loss: 1.4013 - val_accuracy: 0.4947
# Epoch 61/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.7770 - accuracy: 0.6237 - val_loss: 1.4245 - val_accuracy: 0.4840
# Epoch 62/100
# 12/12 [==============================] - 2s 138ms/step - loss: 0.7989 - accuracy: 0.6382 - val_loss: 1.3163 - val_accuracy: 0.5319
# Epoch 63/100
# 12/12 [==============================] - 2s 143ms/step - loss: 0.8121 - accuracy: 0.6263 - val_loss: 1.3361 - val_accuracy: 0.5638
# Epoch 64/100
# 12/12 [==============================] - 2s 142ms/step - loss: 0.8047 - accuracy: 0.6263 - val_loss: 1.4545 - val_accuracy: 0.4681
# Epoch 65/100
# 12/12 [==============================] - 2s 139ms/step - loss: 0.7994 - accuracy: 0.6118 - val_loss: 1.4329 - val_accuracy: 0.4840
# Epoch 66/100
# 12/12 [==============================] - 2s 149ms/step - loss: 0.7954 - accuracy: 0.5987 - val_loss: 1.4001 - val_accuracy: 0.5106
# Epoch 67/100
# 12/12 [==============================] - 2s 143ms/step - loss: 0.7779 - accuracy: 0.6145 - val_loss: 1.4094 - val_accuracy: 0.4947
# Epoch 68/100
# 12/12 [==============================] - 2s 150ms/step - loss: 0.7688 - accuracy: 0.6342 - val_loss: 1.4085 - val_accuracy: 0.4894
# Epoch 69/100
# 12/12 [==============================] - 3s 276ms/step - loss: 0.8006 - accuracy: 0.6237 - val_loss: 1.4073 - val_accuracy: 0.5106
# Epoch 70/100
# 12/12 [==============================] - 4s 296ms/step - loss: 0.7474 - accuracy: 0.6566 - val_loss: 1.4140 - val_accuracy: 0.5053
# Epoch 71/100
# 12/12 [==============================] - 4s 336ms/step - loss: 0.7489 - accuracy: 0.6539 - val_loss: 1.4505 - val_accuracy: 0.4734
# Epoch 72/100
# 12/12 [==============================] - 4s 330ms/step - loss: 0.7770 - accuracy: 0.6395 - val_loss: 1.3763 - val_accuracy: 0.4840
# Epoch 73/100
# 12/12 [==============================] - 3s 294ms/step - loss: 0.7765 - accuracy: 0.6408 - val_loss: 1.4186 - val_accuracy: 0.5106
# Epoch 74/100
# 12/12 [==============================] - 4s 318ms/step - loss: 0.7650 - accuracy: 0.6342 - val_loss: 1.4061 - val_accuracy: 0.5053
# Epoch 75/100
# 12/12 [==============================] - 4s 340ms/step - loss: 0.7700 - accuracy: 0.6461 - val_loss: 1.3778 - val_accuracy: 0.5053
# Epoch 76/100
# 12/12 [==============================] - 4s 310ms/step - loss: 0.7589 - accuracy: 0.6487 - val_loss: 1.3128 - val_accuracy: 0.5638
# Epoch 77/100
# 12/12 [==============================] - 4s 359ms/step - loss: 0.7683 - accuracy: 0.6250 - val_loss: 1.3799 - val_accuracy: 0.5266
# Epoch 78/100
# 12/12 [==============================] - 4s 326ms/step - loss: 0.7506 - accuracy: 0.6487 - val_loss: 1.3856 - val_accuracy: 0.5000
# Epoch 79/100
# 12/12 [==============================] - 4s 350ms/step - loss: 0.7606 - accuracy: 0.6553 - val_loss: 1.3191 - val_accuracy: 0.5213
# Epoch 80/100
# 12/12 [==============================] - 4s 302ms/step - loss: 0.7232 - accuracy: 0.6684 - val_loss: 1.2901 - val_accuracy: 0.5479
# Epoch 81/100
# 12/12 [==============================] - 4s 312ms/step - loss: 0.7339 - accuracy: 0.6671 - val_loss: 1.2933 - val_accuracy: 0.5479
# Epoch 82/100
# 12/12 [==============================] - 4s 328ms/step - loss: 0.7451 - accuracy: 0.6421 - val_loss: 1.3179 - val_accuracy: 0.5319
# Epoch 83/100
# 12/12 [==============================] - 4s 342ms/step - loss: 0.7622 - accuracy: 0.6421 - val_loss: 1.3320 - val_accuracy: 0.5053
# Epoch 84/100
# 12/12 [==============================] - 4s 360ms/step - loss: 0.7598 - accuracy: 0.6513 - val_loss: 1.3261 - val_accuracy: 0.5266
# Epoch 85/100
# 12/12 [==============================] - 4s 346ms/step - loss: 0.7214 - accuracy: 0.6618 - val_loss: 1.2431 - val_accuracy: 0.5585
# Epoch 86/100
# 12/12 [==============================] - 4s 320ms/step - loss: 0.7520 - accuracy: 0.6487 - val_loss: 1.3041 - val_accuracy: 0.5266
# Epoch 87/100
# 12/12 [==============================] - 4s 366ms/step - loss: 0.7233 - accuracy: 0.6605 - val_loss: 1.2277 - val_accuracy: 0.5479
# Epoch 88/100
# 12/12 [==============================] - 4s 335ms/step - loss: 0.7322 - accuracy: 0.6816 - val_loss: 1.2565 - val_accuracy: 0.5426
# Epoch 89/100
# 12/12 [==============================] - 4s 313ms/step - loss: 0.7422 - accuracy: 0.6513 - val_loss: 1.2985 - val_accuracy: 0.5532
# Epoch 90/100
# 12/12 [==============================] - 4s 326ms/step - loss: 0.7456 - accuracy: 0.6645 - val_loss: 1.2716 - val_accuracy: 0.5638
# Epoch 91/100
# 12/12 [==============================] - 4s 339ms/step - loss: 0.7247 - accuracy: 0.6711 - val_loss: 1.2600 - val_accuracy: 0.5479
# Epoch 92/100
# 12/12 [==============================] - 4s 361ms/step - loss: 0.7336 - accuracy: 0.6526 - val_loss: 1.2545 - val_accuracy: 0.5426
# Epoch 93/100
# 12/12 [==============================] - 4s 349ms/step - loss: 0.7191 - accuracy: 0.6553 - val_loss: 1.2818 - val_accuracy: 0.5266
# Epoch 94/100
# 12/12 [==============================] - 4s 362ms/step - loss: 0.7106 - accuracy: 0.6842 - val_loss: 1.2557 - val_accuracy: 0.5213
# Epoch 95/100
# 12/12 [==============================] - 4s 308ms/step - loss: 0.7384 - accuracy: 0.6579 - val_loss: 1.2369 - val_accuracy: 0.5638
# Epoch 96/100
# 12/12 [==============================] - 4s 299ms/step - loss: 0.7088 - accuracy: 0.6789 - val_loss: 1.2636 - val_accuracy: 0.5372
# Epoch 97/100
# 12/12 [==============================] - 4s 326ms/step - loss: 0.7144 - accuracy: 0.6789 - val_loss: 1.2869 - val_accuracy: 0.5213
# Epoch 98/100
# 12/12 [==============================] - 4s 318ms/step - loss: 0.7378 - accuracy: 0.6632 - val_loss: 1.2627 - val_accuracy: 0.5638
# Epoch 99/100
# 12/12 [==============================] - 4s 318ms/step - loss: 0.6907 - accuracy: 0.6816 - val_loss: 1.2869 - val_accuracy: 0.5372
# Epoch 100/100
# 12/12 [==============================] - 4s 344ms/step - loss: 0.7447 - accuracy: 0.6342 - val_loss: 1.2831 - val_accuracy: 0.5479

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('Hybrid CNN-LSTM model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN-LSTM model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the hybrid CNN-LSTM model

hybrid_cnn_lstm_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of all subjects:',hybrid_cnn_lstm_score[1])

mask = person_test.flatten() == idx_subject
x_test_single = x_test[mask]
y_test_single = y_test[mask]
hybrid_cnn_lstm_score = hybrid_cnn_lstm_model.evaluate(x_test_single, y_test_single, verbose=0)
print('Test accuracy of the one subject that was being trained upon:',hybrid_cnn_lstm_score[1])
# Out:
# Test accuracy of all subjects: 0.3340857923030853
# Test accuracy of the one subject that was being trained upon: 0.41999998688697815
